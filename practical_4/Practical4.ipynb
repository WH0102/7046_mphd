# %% [markdown]
# # MQB7046 MODELLING PUBLIC HEALTH DATA - Multinomial logistic regression
#
# ###### Prepared by Claire Choo (4/4/2024)

# %% [markdown]
# Multinomial logistic regression is a statistical method used to model the relationship between multiple categorical outcome variables and one or more independent variables.
#
# * Data Preparation:
#   - Load the dataset and ensure it is properly formatted.
#   - Convert any categorical variables into dummy variables or use one-hot encoding.
#
#
# * Model Specification:
#   - Import the statsmodels.api module
#   - Define independent variables and dependent variable
#   - Add a constant termther independent variables using sm.add_constant().
#   - Specify the multinomial logistic regression model using sm.MNLog().
#
#
# * Model Fitting:
#   - Fit the model with the data using the .fit() method.
#
#
# * Interpretation and Evaluation:
#   - Interpret the coefficients, p-values, and confidence intervals to assess the significance of the independent variables (or predictors).
#   - Assess the goodness-of-fit of the model using appropriate metrics like pseudo-R squared, likelihood ratio tests, or others.
#   - Consider the odds ratios associated with each predictor variable to assess the magnitude of the effect.

# %% [markdown]
# #### Practical 4
#
# The researchers are interested to examine factors associated with employment status of a group of individuals.
#
# Variable / Definition:
# 1) id  : identification number
# 2) Sex : Gender of participants (Male, Female)
# 3) Age : Age group of participants (25-44,45-54, 55-64)
# 4) Marital: Marital status (Married/Cohabiting, Single, Widowed/Divorced)
# 5) Employment : Employment status (Employed, Nonemployed, Unemployed)

# %%
import pandas as pd
import numpy as np
from mphd import *

# Load the dataset into a DataFrame
df = pd.read_excel(r"open.xlsx")

# Display the first few rows of the DataFrame to verify that the data is loaded correctly
df.head()
# Out:
#    id   Sex    Age             Marital   Employment
# 0   1  Male  55-64  Married/Cohabiting     Employed
# 1   2  Male  25-44  Married/Cohabiting  Nonemployed
# 2   3  Male  25-44  Married/Cohabiting     Employed
# 3   4  Male  55-64  Married/Cohabiting     Employed
# 4   5  Male  55-64  Married/Cohabiting     Employed

# %%
# Check the structure of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741 entries, 0 to 740
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          741 non-null    int64
#  1   Sex         741 non-null    object
#  2   Age         741 non-null    object
#  3   Marital     741 non-null    object
#  4   Employment  741 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 29.1+ KB

# %%
# Descriptive Analysis on the data
categorical_descriptive_analysis(df, independent_variables=df.columns[1:4], dependent_variables="Employment", margins=True)
# Out:
# Descriptive Analysis for independent variables:
# Descriptive Analysis on Sex
# +--------+-------+------------+
# |  Sex   | count | percentage |
# +--------+-------+------------+
# | Female | 396.0 |   53.44    |
# |  Male  | 345.0 |   46.56    |
# |  All   | 741.0 |   100.0    |
# +--------+-------+------------+
# Chi2 test between Sex and Employment have chi2 statistics value = 68.35 and p_value of 0.00
# -----------------------------------------------------
# Descriptive Analysis on Age
# +-------+-------+------------+
# |  Age  | count | percentage |
# +-------+-------+------------+
# | 25-44 | 388.0 |   52.36    |
# | 45-54 | 169.0 |   22.81    |
# | 55-64 | 184.0 |   24.83    |
# |  All  | 741.0 |   100.0    |
# +-------+-------+------------+
# Chi2 test between Age and Employment have chi2 statistics value = 124.44 and p_value of 0.00
# -----------------------------------------------------
# Descriptive Analysis on Marital
# +--------------------+-------+------------+
# |      Marital       | count | percentage |
# +--------------------+-------+------------+
# | Married/Cohabiting | 477.0 |   64.37    |
# |       Single       | 148.0 |   19.97    |
# | Widowed/ Divorced  | 116.0 |   15.65    |
# |        All         | 741.0 |   100.0    |
# +--------------------+-------+------------+
# Chi2 test between Marital and Employment have chi2 statistics value = 97.02 and p_value of 0.00
# -----------------------------------------------------
# Descriptive Analysis for dependent variables:
# +-------------+-------+------------+
# | Employment  | count | percentage |
# +-------------+-------+------------+
# |  Employed   | 546.0 |   73.68    |
# | Nonemployed | 154.0 |   20.78    |
# | Unemployed  | 41.0  |    5.53    |
# |     All     | 741.0 |   100.0    |
# +-------------+-------+------------+

# %%
# Convert categorical variables into numerical labels
data = label_encode(df = df.copy(deep = True), columns= df.columns[1:], prefix = "encoded", convert_numeric = True)

# encoded columns = 
encoded_columns = ["id",] + [x for x in data.columns if "encoded" in x]

# Print the dataframe head
data.head()
# Out:
#    id   Sex    Age             Marital   Employment  encoded_Sex  encoded_Age  \
# 0   1  Male  55-64  Married/Cohabiting     Employed            1            2
# 1   2  Male  25-44  Married/Cohabiting  Nonemployed            1            0
# 2   3  Male  25-44  Married/Cohabiting     Employed            1            0
# 3   4  Male  55-64  Married/Cohabiting     Employed            1            2
# 4   5  Male  55-64  Married/Cohabiting     Employed            1            2
#
#    encoded_Marital  encoded_Employment
# 0                0                   0
# 1                0                   1
# 2                0                   0
# 3                0                   0
# 4                0                   0

# %%
# Convert X to dummy variables
dummy_df = pd.get_dummies(df, columns = df.columns[1:], dtype = int)
dummy_df.head()
# Out:
#    id  Sex_Female  Sex_Male  Age_25-44  Age_45-54  Age_55-64  \
# 0   1           0         1          0          0          1
# 1   2           0         1          1          0          0
# 2   3           0         1          1          0          0
# 3   4           0         1          0          0          1
# 4   5           0         1          0          0          1
#
#    Marital_Married/Cohabiting  Marital_Single  Marital_Widowed/ Divorced  \
# 0                           1               0                          0
# 1                           1               0                          0
# 2                           1               0                          0
# 3                           1               0                          0
# 4                           1               0                          0
#
#    Employment_Employed  Employment_Nonemployed  Employment_Unemployed
# 0                    1                       0                      0
# 1                    0                       1                      0
# 2                    1                       0                      0
# 3                    1                       0                      0
# 4                    1                       0                      0

# %% [markdown]
# # Run multinomial logistic regression

# %%
# Test 1: Single Independent Variable (Sex) with Single Target Variable
#add constant
sex_only_model = multinominal_logistic_regression(data, mode ="sm.MNLogit", x=("encoded_Sex",), y = "encoded_Employment")
sex_only_model_assessment = assess_model_fitness(sex_only_model, "Employment ~ Sex")
sex_only_model_assessment.round(4)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.695885
#          Iterations 7
#                                Employment ~ Sex
# ==============================================================================
# Dep. Variable:     encoded_Employment   No. Observations:                  741
# Model:                        MNLogit   Df Residuals:                      737
# Method:                           MLE   Df Model:                            2
# Date:                Mon, 15 Apr 2024   Pseudo R-squ.:                 0.02219
# Time:                        08:58:31   Log-Likelihood:                -515.65
# converged:                       True   LL-Null:                       -527.35
# Covariance Type:            nonrobust   LLR p-value:                 8.291e-06
# ========================================================================================
# encoded_Employment=1       coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.9200      0.114     -8.085      0.000      -1.143      -0.697
# encoded_Sex             -0.8681      0.196     -4.435      0.000      -1.252      -0.484
# ----------------------------------------------------------------------------------------
# encoded_Employment=2       coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -2.7689      0.250    -11.074      0.000      -3.259      -2.279
# encoded_Sex              0.3302      0.328      1.006      0.315      -0.313       0.974
# ========================================================================================
# Odd Ratio =
# +-------------+--------+--------+
# |             |   0    |   1    |
# +-------------+--------+--------+
# |    const    | 0.3985 | 0.0627 |
# | encoded_Sex | 0.4197 | 1.3912 |
# +-------------+--------+--------+
# None
# Likelihood ratio = 23.4007 with p value of 0.0000
# Pseudo R-squared value = 0.02219
# Akaike Information Criterion (AIC) = 1,039.3020
# Bayesin Information Criterion (BIC) = 1,057.7340
#          model_name  likelihood_ratio  llr_p_value  pseudo-r-squared  \
# 0  Employment ~ Sex           23.4007          0.0            0.0222
#
#    aic_akaike_information_criterion  bic_bayesin_information_criterion
# 0                          1039.302                           1057.734

# %%
### Test 2: Adding more IVs in the model
independent_variable_list = iterate_independent_variables(independent_variables=encoded_columns[1:4], dependent_variables=encoded_columns[4])
columns_for_independent_variable_list = independent_variable_list[0]
formula_list = independent_variable_list[1]
model_list = [multinominal_logistic_regression(data, mode = "smf.ols", formula = formula) for formula in formula_list]

assessment_df = pd.DataFrame()

for num in range(0, len(model_list)):
    # assessment_df = pd.concat([assessment_df, assess_model_fitness(model_list[num], title = formula_list[num])])
    print(model_list[num].summary(title = formula_list[num]))
    print(f"Odd ratio for = {formula_list[num]}")
    print(np.exp(model_list[num].params).round(4).to_markdown(tablefmt = "pretty"))
    #                             "p_values":[model_list[num].pvalues],
    temp_df = pd.DataFrame({"model_name":[formula_list[num]],
                            "Log-Likelihood":[model_list[num].llf],
                            "R-Squared":[model_list[num].rsquared],
                            "F-statistic":[model_list[num].fvalue],
                            "F-p_value":[model_list[num].f_pvalue],
                            "aic_akaike_information_criterion":[model_list[num].aic], 
                            "bic_bayesin_information_criterion":[model_list[num].bic]})
    assessment_df = pd.concat([assessment_df, temp_df], ignore_index = True)
    print("-------------------------------------------------------------------------------------------------------")
# Out:
#                        encoded_Employment ~ encoded_Sex
# ==============================================================================
# Dep. Variable:     encoded_Employment   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     4.185
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):             0.0411
# Time:                        09:36:00   Log-Likelihood:                -636.01
# No. Observations:                 741   AIC:                             1276.
# Df Residuals:                     739   BIC:                             1285.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.3586      0.029     12.483      0.000       0.302       0.415
# encoded_Sex    -0.0861      0.042     -2.046      0.041      -0.169      -0.003
# ==============================================================================
# Omnibus:                      211.540   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              430.460
# Skew:                           1.647   Prob(JB):                     3.36e-94
# Kurtosis:                       4.757   Cond. No.                         2.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Odd ratio for = encoded_Employment ~ encoded_Sex
# +-------------+--------+
# |             |   0    |
# +-------------+--------+
# |  Intercept  | 1.4313 |
# | encoded_Sex | 0.9175 |
# +-------------+--------+
# -------------------------------------------------------------------------------------------------------
#                        encoded_Employment ~ encoded_Age
# ==============================================================================
# Dep. Variable:     encoded_Employment   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     5.703
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):             0.0172
# Time:                        09:36:00   Log-Likelihood:                -635.25
# No. Observations:                 741   AIC:                             1275.
# Df Residuals:                     739   BIC:                             1284.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.2750      0.028      9.896      0.000       0.220       0.330
# encoded_Age     0.0600      0.025      2.388      0.017       0.011       0.109
# ==============================================================================
# Omnibus:                      212.317   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              433.684
# Skew:                           1.650   Prob(JB):                     6.71e-95
# Kurtosis:                       4.777   Cond. No.                         2.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Odd ratio for = encoded_Employment ~ encoded_Age
# +-------------+--------+
# |             |   0    |
# +-------------+--------+
# |  Intercept  | 1.3165 |
# | encoded_Age | 1.0619 |
# +-------------+--------+
# -------------------------------------------------------------------------------------------------------
#                      encoded_Employment ~ encoded_Marital
# ==============================================================================
# Dep. Variable:     encoded_Employment   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     21.06
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):           5.24e-06
# Time:                        09:36:00   Log-Likelihood:                -627.69
# No. Observations:                 741   AIC:                             1259.
# Df Residuals:                     739   BIC:                             1269.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.2534      0.025     10.073      0.000       0.204       0.303
# encoded_Marital     0.1270      0.028      4.589      0.000       0.073       0.181
# ==============================================================================
# Omnibus:                      187.388   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              347.993
# Skew:                           1.529   Prob(JB):                     2.72e-76
# Kurtosis:                       4.384   Cond. No.                         1.91
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Odd ratio for = encoded_Employment ~ encoded_Marital
# +-----------------+--------+
# |                 |   0    |
# +-----------------+--------+
# |    Intercept    | 1.2883 |
# | encoded_Marital | 1.1354 |
# +-----------------+--------+
# -------------------------------------------------------------------------------------------------------
#                 encoded_Employment ~ encoded_Sex + encoded_Age
# ==============================================================================
# Dep. Variable:     encoded_Employment   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     5.507
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):            0.00423
# Time:                        09:36:00   Log-Likelihood:                -632.61
# No. Observations:                 741   AIC:                             1271.
# Df Residuals:                     738   BIC:                             1285.
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.3160      0.033      9.588      0.000       0.251       0.381
# encoded_Sex    -0.0968      0.042     -2.297      0.022      -0.180      -0.014
# encoded_Age     0.0657      0.025      2.607      0.009       0.016       0.115
# ==============================================================================
# Omnibus:                      220.621   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              469.386
# Skew:                           1.680   Prob(JB):                    1.19e-102
# Kurtosis:                       4.979   Cond. No.                         3.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Odd ratio for = encoded_Employment ~ encoded_Sex + encoded_Age
# +-------------+--------+
# |             |   0    |
# +-------------+--------+
# |  Intercept  | 1.3716 |
# | encoded_Sex | 0.9077 |
# | encoded_Age | 1.0679 |
# +-------------+--------+
# -------------------------------------------------------------------------------------------------------
#               encoded_Employment ~ encoded_Sex + encoded_Marital
# ==============================================================================
# Dep. Variable:     encoded_Employment   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     11.73
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):           9.68e-06
# Time:                        09:36:00   Log-Likelihood:                -626.51
# No. Observations:                 741   AIC:                             1259.
# Df Residuals:                     738   BIC:                             1273.
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.2859      0.033      8.697      0.000       0.221       0.350
# encoded_Sex        -0.0644      0.042     -1.536      0.125      -0.147       0.018
# encoded_Marital     0.1219      0.028      4.378      0.000       0.067       0.177
# ==============================================================================
# Omnibus:                      191.344   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              361.796
# Skew:                           1.542   Prob(JB):                     2.73e-79
# Kurtosis:                       4.486   Cond. No.                         3.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Odd ratio for = encoded_Employment ~ encoded_Sex + encoded_Marital
# +-----------------+--------+
# |                 |   0    |
# +-----------------+--------+
# |    Intercept    | 1.331  |
# |   encoded_Sex   | 0.9377 |
# | encoded_Marital | 1.1297 |
# +-----------------+--------+
# -------------------------------------------------------------------------------------------------------
#               encoded_Employment ~ encoded_Age + encoded_Marital
# ==============================================================================
# Dep. Variable:     encoded_Employment   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     13.44
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):           1.85e-06
# Time:                        09:36:00   Log-Likelihood:                -624.85
# No. Observations:                 741   AIC:                             1256.
# Df Residuals:                     738   BIC:                             1270.
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.2108      0.031      6.845      0.000       0.150       0.271
# encoded_Age         0.0592      0.025      2.384      0.017       0.010       0.108
# encoded_Marital     0.1265      0.028      4.585      0.000       0.072       0.181
# ==============================================================================
# Omnibus:                      194.346   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              372.403
# Skew:                           1.553   Prob(JB):                     1.36e-81
# Kurtosis:                       4.554   Cond. No.                         2.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Odd ratio for = encoded_Employment ~ encoded_Age + encoded_Marital
# +-----------------+--------+
# |                 |   0    |
# +-----------------+--------+
# |    Intercept    | 1.2346 |
# |   encoded_Age   | 1.0609 |
# | encoded_Marital | 1.1348 |
# +-----------------+--------+
# -------------------------------------------------------------------------------------------------------
#        encoded_Employment ~ encoded_Sex + encoded_Age + encoded_Marital
# ==============================================================================
# Dep. Variable:     encoded_Employment   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     10.05
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):           1.70e-06
# Time:                        09:36:00   Log-Likelihood:                -623.25
# No. Observations:                 741   AIC:                             1254.
# Df Residuals:                     737   BIC:                             1273.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.2455      0.036      6.749      0.000       0.174       0.317
# encoded_Sex        -0.0749      0.042     -1.787      0.074      -0.157       0.007
# encoded_Age         0.0636      0.025      2.553      0.011       0.015       0.112
# encoded_Marital     0.1205      0.028      4.344      0.000       0.066       0.175
# ==============================================================================
# Omnibus:                      200.046   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              394.158
# Skew:                           1.572   Prob(JB):                     2.57e-86
# Kurtosis:                       4.698   Cond. No.                         3.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Odd ratio for = encoded_Employment ~ encoded_Sex + encoded_Age + encoded_Marital
# +-----------------+--------+
# |                 |   0    |
# +-----------------+--------+
# |    Intercept    | 1.2783 |
# |   encoded_Sex   | 0.9278 |
# |   encoded_Age   | 1.0656 |
# | encoded_Marital | 1.1281 |
# +-----------------+--------+
# -------------------------------------------------------------------------------------------------------

# %%
assessment_df.round(4)
# Out:
#                                           model_name  Log-Likelihood  \
# 0                   encoded_Employment ~ encoded_Sex       -636.0071
# 1                   encoded_Employment ~ encoded_Age       -635.2513
# 2               encoded_Employment ~ encoded_Marital       -627.6901
# 3     encoded_Employment ~ encoded_Sex + encoded_Age       -632.6108
# 4  encoded_Employment ~ encoded_Sex + encoded_Mar...       -626.5070
# 5  encoded_Employment ~ encoded_Age + encoded_Mar...       -624.8469
# 6  encoded_Employment ~ encoded_Sex + encoded_Age...       -623.2453
#
#    R-Squared  F-statistic  F-p_value  aic_akaike_information_criterion  \
# 0     0.0056       4.1851     0.0411                         1276.0143
# 1     0.0077       5.7027     0.0172                         1274.5026
# 2     0.0277      21.0569     0.0000                         1259.3802
# 3     0.0147       5.5071     0.0042                         1271.2217
# 4     0.0308      11.7280     0.0000                         1259.0141
# 5     0.0351      13.4378     0.0000                         1255.6938
# 6     0.0393      10.0494     0.0000                         1254.4906
#
#    bic_bayesin_information_criterion
# 0                          1285.2303
# 1                          1283.7186
# 2                          1268.5962
# 3                          1285.0457
# 4                          1272.8381
# 5                          1269.5178
# 6                          1272.9226

# %%
model_list[6].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     encoded_Employment   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     10.05
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):           1.70e-06
# Time:                        10:45:10   Log-Likelihood:                -623.25
# No. Observations:                 741   AIC:                             1254.
# Df Residuals:                     737   BIC:                             1273.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.2455      0.036      6.749      0.000       0.174       0.317
# encoded_Sex        -0.0749      0.042     -1.787      0.074      -0.157       0.007
# encoded_Age         0.0636      0.025      2.553      0.011       0.015       0.112
# encoded_Marital     0.1205      0.028      4.344      0.000       0.066       0.175
# ==============================================================================
# Omnibus:                      200.046   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              394.158
# Skew:                           1.572   Prob(JB):                     2.57e-86
# Kurtosis:                       4.698   Cond. No.                         3.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# VIF?

# %%
# Comparing model 2 and model 1 using AIC, BIC
